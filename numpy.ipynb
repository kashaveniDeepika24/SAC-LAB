# %%
import numpy as np

# %%
arrayex5=np.array((12,13,14))
arrayex5
# Out:
# array([12, 13, 14])

# %%
import numpy as np
arr=np.array([10,20,30,40,50])
mean_val=np.mean(arr)
std_dev=np.std(arr)
max_val=np.max(arr)
min_val=np.min(arr)
print("Array:",arr)
print("mean:",mean_val)
print("standard Deviation:",std_dev)
print("Maximum:",max_val)
print("Minimum:",min_val)
# Out:
# Array: [10 20 30 40 50]
# mean: 30.0
# standard Deviation: 14.142135623730951
# Maximum: 50
# Minimum: 10

# %%
import numpy as np
A=np.array([[1,2],[3,4]])
B=np.array([[5,6],[7,8]])
C=np.dot(A,B)
print("matrix A:/n",A)
print("matrix B:/n",B)
print("matix multiplication (A*B):/n",C)
# Out:
# matrix A:/n [[1 2]
#  [3 4]]
# matrix B:/n [[5 6]
#  [7 8]]
# matix multiplication (A*B):/n [[19 22]
#  [43 50]]

# %% [markdown]
# array1=np.array([1,2,3,4,5])
# array1
# print(array1.ndim)

# %%
array1=np.array([1,2,3,4,5])
array1
print(array1.ndim)
# Out:
# 1

# %%
arrex=np.array([1,2,3,4])
arrex
# Out:
# array([1, 2, 3, 4])

# %%
arrex.shape
# Out:
# (4,)

# %%
A=np.array([1,2])
A
print(A[1])
# Out:
# 2

# %%
array7=np.array([[1,2],[3.3,4]])
array7
# Out:
# array([[1. , 2. ],
#        [3.3, 4. ]])

# %%
char_arr=np.array(['a','b','c'])
char_arr
# Out:
# array(['a', 'b', 'c'], dtype='<U1')

# %%
ch_arr2=np.array(['supervised','unisupervised','semi-supervised','reinforcment'])
low_arr=np.char.lower(ch_arr2)
low_arr
# Out:
# array(['supervised', 'unisupervised', 'semi-supervised', 'reinforcment'],
#       dtype='<U15')

# %%
cleaned_arr=np.char.replace(low_arr,"")
