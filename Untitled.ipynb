# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("cse(ai-b).csv")
print(df)
# Out:
#     Roll_no  SAC marks
# 0        67         16
# 1        68         94
# 2        69         89
# 3        70         51
# 4        71         15
# 5        72         25
# 6        73         15
# 7        74         16
# 8        75         65
# 9        76         16
# 10       77         65
# 11       78         65
# 12       79         34
# 13       80         36
# 14       81         56
# 15       82         32
# 16       83         89
# 17       84         65
# 18       85         32
# 19       86         84
# 20       87         65
# 21       88         89
# 22       89         87
# 23       90         65
# 24       91         65
# 25       92         54
# 26       93         54
# 27       94         87
# 28       95         67
# 29       96         67
# 30       97         75

# %%
#BAR PLOT
df['SAC marks'].plot(kind="pie")
plt.title("pie plot")
plt.show()

# %%
df.plot(kind='bar',x='Roll_no',y='SAC marks')
# Out:
# <Axes: xlabel='Roll_no'>

# %%
df.plot(kind='pie',x='Roll_no',y='SAC marks')
# Out:
# <Axes: ylabel='SAC marks'>

# %%
#BAR PLOT
df['SAC marks'].plot(kind="bar")
plt.title("bar plot")
plt.show()

# %%
df['SAC marks'].plot(kind="hist")
plt.title("histogram")
plt.show()
